# %% [markdown]
# # Python Demo Code for evaluation
# OBS.: Did not find real results for Dataset val2017. This code will not run as expected
#
# Original file: https://github.com/cocodataset/cocoapi/blob/master/PythonAPI/pycocoEvalDemo.ipynb

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import numpy as np
import skimage.io as io
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
annType = ['segm','bbox','keypoints']
annType = annType[1]      #specify type here
prefix = 'person_keypoints' if annType=='keypoints' else 'instances'
print ('Running demo for *%s* results.'%(annType))
# Out:
# Running demo for *bbox* results.

# %%
#initialize COCO ground truth api
#dataDir='../'
dataType='val2017'
#annFile = '%s/annotations/%s_%s.json'%(dataDir,prefix,dataType)
annFile = 'annotations/%s_%s.json'%(prefix,dataType)
print ('File:',annFile)
cocoGt=COCO(annFile)
# Out:
# File: annotations/instances_val2017.json
# loading annotations into memory...
# Done (t=0.50s)
# creating index...
# index created!

# %%
#initialize COCO detections api
#resFile='%s/results/%s_%s_fake%s100_results.json'
#resFile = resFile%(dataDir, prefix, dataType, annType)
resFile='results/%s_%s_fake%s100_results.json'
resFile = resFile%(prefix, dataType, annType)
print ('File:',resFile)
cocoDt=cocoGt.loadRes(resFile)
# Out:
# File: results/instances_val2017_fakebbox100_results.json
# Loading and preparing results...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[12], line 7
#       5 resFile = resFile%(prefix, dataType, annType)
#       6 print ('File:',resFile)
# ----> 7 cocoDt=cocoGt.loadRes(resFile)
#
# File c:\Users\Diogenes\AppData\Local\Programs\Python\Python313\Lib\site-packages\pycocotools\coco.py:321, in COCO.loadRes(self, resFile)
#     319 if type(resFile) == str or (PYTHON_VERSION == 2 and type(resFile) == unicode):
#     320     with open(resFile) as f:
# --> 321         anns = json.load(f)
#     322 elif type(resFile) == np.ndarray:
#     323     anns = self.loadNumpyAnnotations(resFile)
#
# File c:\Users\Diogenes\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
imgIds=sorted(cocoGt.getImgIds())
imgIds=imgIds[0:100]
imgId = imgIds[np.random.randint(100)]

# %%
# running evaluation
cocoEval = COCOeval(cocoGt,cocoDt,annType)
cocoEval.params.imgIds  = imgIds
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # running evaluation
# ----> 2 cocoEval = COCOeval(cocoGt,cocoDt,annType)
#       3 cocoEval.params.imgIds  = imgIds
#       4 cocoEval.evaluate()
#
# NameError: name 'cocoDt' is not defined
